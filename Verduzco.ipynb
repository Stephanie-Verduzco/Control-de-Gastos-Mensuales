# %% [markdown]
# <a href="https://colab.research.google.com/github/Stephanie-Verduzco/Control-de-Gastos-Mensuales/blob/main/Verduzco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs
X, y_true = make_blobs(n_samples=300, centers=6,
                       cluster_std=10, random_state=0)
X = X[:, ::-1]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(5, random_state=0)
labels = kmeans.fit(X).predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis');
